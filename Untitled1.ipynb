# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("president_polls_2016.csv")

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#    cycle     branch        type                        matchup forecastdate  \
# 0   2016  President  polls-plus  Clinton vs. Trump vs. Johnson      11/8/16
# 1   2016  President  polls-plus  Clinton vs. Trump vs. Johnson      11/8/16
# 2   2016  President  polls-plus  Clinton vs. Trump vs. Johnson      11/8/16
# 3   2016  President  polls-plus  Clinton vs. Trump vs. Johnson      11/8/16
# 4   2016  President  polls-plus  Clinton vs. Trump vs. Johnson      11/8/16
#
#   state  startdate    enddate                  pollster grade  ...  \
# 0  U.S.  11/3/2016  11/6/2016  ABC News/Washington Post    A+  ...
# 1  U.S.  11/1/2016  11/7/2016   Google Consumer Surveys     B  ...
# 2  U.S.  11/2/2016  11/6/2016                     Ipsos    A-  ...
# 3  U.S.  11/4/2016  11/7/2016                    YouGov     B  ...
# 4  U.S.  11/3/2016  11/6/2016          Gravis Marketing    B-  ...
#
#    adjpoll_clinton adjpoll_trump  adjpoll_johnson  adjpoll_mcmullin  \
# ...

# %%
df[['state','grade']].value_counts()
# Out:
# state          grade
# U.S.           A-       1215
#                C+        546
#                B         162
#                C-        126
#                A+        114
#                         ...
# Nebraska CD-1  B           3
# Indiana        A           3
# Nebraska CD-2  B           3
# Missouri       A           3
# Mississippi    C           3
# Name: count, Length: 321, dtype: int64

# %%
category_counts = df['state'].value_counts().reset_index(name='Count_Category')
value_counts = df['grade'].value_counts().reset_index(name='Count_Value')

# Display the counts
print(category_counts)
print(value_counts)
# Out:
#                    index  Count_Category
# 0                   U.S.            3318
# 1                Florida             444
# 2         North Carolina             375
# 3           Pennsylvania             375
# 4                   Ohio             345
# 5          New Hampshire             336
# 6                 Nevada             279
# 7               Virginia             273
# 8               Michigan             258
# 9              Wisconsin             240
# 10              Colorado             240
# 11               Georgia             240
# 12               Arizona             237
# 13            California             213
# 14                  Iowa             210
# 15              Missouri             204
# 16                  Utah             198
# 17              New York             189
# 18              Illinois             180
# 19                 Texas             174
# 20               Indiana             168
# 21                Oregon             162
# ...

# %%
combination_counts = df.groupby(['state','grade']).size().reset_index(name='Count')

# %%
print(combination_counts)
# Out:
#          state grade  Count
# 0      Alabama    A-     42
# 1      Alabama     B     45
# 2      Alabama    C-     36
# 3       Alaska     B     57
# 4       Alaska    B+      6
# ..         ...   ...    ...
# 316  Wisconsin    B-     18
# 317  Wisconsin    C-     42
# 318    Wyoming     B     45
# 319    Wyoming    B-      3
# 320    Wyoming    C-     36
#
# [321 rows x 3 columns]

# %%
df.head()
# Out:
#    cycle     branch        type                        matchup forecastdate  \
# 0   2016  President  polls-plus  Clinton vs. Trump vs. Johnson      11/8/16
# 1   2016  President  polls-plus  Clinton vs. Trump vs. Johnson      11/8/16
# 2   2016  President  polls-plus  Clinton vs. Trump vs. Johnson      11/8/16
# 3   2016  President  polls-plus  Clinton vs. Trump vs. Johnson      11/8/16
# 4   2016  President  polls-plus  Clinton vs. Trump vs. Johnson      11/8/16
#
#   state  startdate    enddate                  pollster grade  ...  \
# 0  U.S.  11/3/2016  11/6/2016  ABC News/Washington Post    A+  ...
# 1  U.S.  11/1/2016  11/7/2016   Google Consumer Surveys     B  ...
# 2  U.S.  11/2/2016  11/6/2016                     Ipsos    A-  ...
# 3  U.S.  11/4/2016  11/7/2016                    YouGov     B  ...
# 4  U.S.  11/3/2016  11/6/2016          Gravis Marketing    B-  ...
#
#    adjpoll_clinton adjpoll_trump  adjpoll_johnson  adjpoll_mcmullin  \
# ...
